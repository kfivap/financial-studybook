# %%
import yfinance as yf
from datetime import datetime, timedelta

start_date = datetime.now() - timedelta(days=10)
end_date = datetime.now()
interval = '1h'

df = yf.download('BTC-USD', start=start_date, end=end_date, interval=interval)
df.columns= df.columns.str.lower()
df.to_csv('out.csv')  
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    open          high           low  \
# Datetime
# 2023-04-05 20:00:00+00:00  28249.189453  28301.322266  28135.736328
# 2023-04-05 21:00:00+00:00  28145.939453  28220.265625  28145.939453
# 2023-04-05 22:00:00+00:00  28164.031250  28227.916016  28132.453125
# 2023-04-05 23:00:00+00:00  28178.544922  28202.958984  28147.273438
# 2023-04-06 00:00:00+00:00  28175.226562  28178.384766  27944.873047
# ...                                 ...           ...           ...
# 2023-04-15 11:00:00+00:00  30441.675781  30455.542969  30398.558594
# 2023-04-15 12:00:00+00:00  30418.755859  30470.589844  30407.908203
# 2023-04-15 13:00:00+00:00  30455.041016  30464.355469  30327.597656
# 2023-04-15 14:00:00+00:00  30360.894531  30403.548828  30331.224609
# 2023-04-15 15:00:00+00:00  30384.125000  30436.167969  30382.906250
#
#                                   close     adj close     volume
# Datetime
# 2023-04-05 20:00:00+00:00  28135.736328  28135.736328          0
# 2023-04-05 21:00:00+00:00  28186.613281  28186.613281  119246848
# 2023-04-05 22:00:00+00:00  28183.134766  28183.134766   14937088
# 2023-04-05 23:00:00+00:00  28175.435547  28175.435547          0
# 2023-04-06 00:00:00+00:00  27978.080078  27978.080078          0
# ...                                 ...           ...        ...
# 2023-04-15 11:00:00+00:00  30416.298828  30416.298828          0
# 2023-04-15 12:00:00+00:00  30451.261719  30451.261719          0
# 2023-04-15 13:00:00+00:00  30361.736328  30361.736328          0
# 2023-04-15 14:00:00+00:00  30380.390625  30380.390625          0
# 2023-04-15 15:00:00+00:00  30426.542969  30426.542969          0
#
# [236 rows x 6 columns]

# %%
import mplfinance as mpf
cutDf = df.loc['2023-04-05':]
mpf.plot(cutDf, type='candle', style='yahoo', volume=True, mav = (5,30))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 4
#       2 cutDf = df.loc['2023-04-05':]
#       3 mpf.plot(cutDf, type='candle', style='yahoo', volume=True, mav = (5,30))
# ----> 4 mpf.list
#
# AttributeError: module 'mplfinance' has no attribute 'list'
