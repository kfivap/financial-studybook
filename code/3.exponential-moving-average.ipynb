# %%
import pandas as pd
import numpy as np
import mplfinance as mpf

df = pd.read_csv("./BTC-USD.csv", index_col='Date', parse_dates=True)
df
# Out:
#                     open          high           low         close  \
# Date
# 2023-01-16  20882.224609  21360.875000  20715.746094  21169.632812
# 2023-01-17  21175.833984  21438.660156  20978.533203  21161.519531
# 2023-01-18  21161.050781  21564.501953  20541.544922  20688.781250
# 2023-01-19  20686.746094  21163.011719  20685.380859  21086.792969
# 2023-01-20  21085.373047  22692.357422  20919.126953  22676.552734
# ...                  ...           ...           ...           ...
# 2023-04-12  30231.582031  30462.480469  29725.574219  30139.052734
# 2023-04-13  29892.740234  30539.845703  29878.623047  30399.066406
# 2023-04-14  30409.562500  31005.607422  30044.498047  30485.699219
# 2023-04-15  30490.750000  30601.740234  30245.882812  30318.496094
# 2023-04-16  30313.685547  30407.398438  30191.646484  30245.451172
#
#                adj close       volume
# Date
# 2023-01-16  21169.632812  26792494050
# 2023-01-17  21161.519531  24999983362
# ...

# %%
# manual implementration
def calc_ema(prices,dates, period):
    alpha = 2 / (period + 1)
    # print(alpha)
    ema = [(str(np.datetime_as_string(dates[0], unit='D')), prices[0])]
    for i in range(1, len(prices)):
        date = str(np.datetime_as_string(dates[i], unit='D'))
        ema_val = alpha * prices[i] + (1 - alpha) * ema[i-1][1]
        ema.append((date,ema_val))
    return ema
    
prices = df['close'].to_list()
dates = df.index.values

ema_lines = dict(alines= [calc_ema(prices,dates, 5), calc_ema(prices,dates, 10), calc_ema(prices,dates, 30) ], colors=['#ce17eb','#17a1eb', '#bdeb17'],linewidths=(0.5,0.5,0.5))
mpf.plot(df, type='candle', style='yahoo', volume=True, figratio=(8,4), alines = ema_lines)

# %%
# one-line using libs methods
mpf.plot(df, type='candle', style='yahoo', volume=True, figratio=(8,4),ema=(5, 10, 30))

# %%
# one line add to df and plot
df['ewm5'] = df['close'].ewm(span=5).mean()
df['ewm10'] = df['close'].ewm(span=10).mean()
df['ewm30'] = df['close'].ewm(span=30).mean()

ap =  [   
    mpf.make_addplot(df['ewm5'], panel=0, width=0.75), 
    mpf.make_addplot(df['ewm10'], panel=0, width=0.75),  
    mpf.make_addplot(df['ewm30'], panel=0, width=0.75),  
]

mpf.plot(df, type='candle', style='yahoo', volume=True, figratio=(8,4), addplot=ap)
